# %%
import sys
sys.path.append("../src")

from preprocessing import preprocess_and_split
from train import train_and_evaluate

X_train, X_val, y_train, y_val = preprocess_and_split(
    input_path="../data/raw/telco_churn.csv"
)

best_model = train_and_evaluate(X_train, X_val, y_train, y_val)
print("Training complete. Best model:", best_model)
# Out:
# LOGISTIC_REGRESSION ROC-AUC: 0.8419
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1035
#            1       0.66      0.56      0.60       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409
#
#
# RANDOM_FOREST ROC-AUC: 0.8185
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1035
#            1       0.62      0.47      0.53       374
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.68      0.70      1409
# weighted avg       0.77      0.78      0.77      1409
#
#
# XGBOOST ROC-AUC: 0.8368
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87      1035
#            1       0.64      0.53      0.58       374
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.79      0.80      0.79      1409
#
#
# ✅ Best model saved with ROC-AUC: 0.8419
# Training complete. Best model: LogisticRegression(max_iter=1000)
